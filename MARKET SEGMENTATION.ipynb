# %% [markdown]
# #    Market_Segmentation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sklearn
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.cluster import AgglomerativeClustering
import requests
import warnings
warnings.filterwarnings("ignore")

# %%
url ="https://homepage.boku.ac.at/leisch/MSA/datasets/mcdonalds.csv"
data=pd.read_csv(url)
data.head()
# Out:
#   yummy convenient spicy fattening greasy fast cheap tasty expensive healthy  \
# 0    No        Yes    No       Yes     No  Yes   Yes    No       Yes      No
# 1   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes       Yes      No
# 2    No        Yes   Yes       Yes    Yes  Yes    No   Yes       Yes     Yes
# 3   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes        No      No
# 4    No        Yes    No       Yes    Yes  Yes   Yes    No        No     Yes
#
#   disgusting Like  Age      VisitFrequency  Gender
# 0         No   -3   61  Every three months  Female
# 1         No   +2   51  Every three months  Female
# 2         No   +1   62  Every three months  Female
# 3        Yes   +4   69         Once a week  Female
# 4         No   +2   49        Once a month    Male

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   yummy           1453 non-null   object
#  1   convenient      1453 non-null   object
#  2   spicy           1453 non-null   object
#  3   fattening       1453 non-null   object
#  4   greasy          1453 non-null   object
#  5   fast            1453 non-null   object
#  6   cheap           1453 non-null   object
#  7   tasty           1453 non-null   object
#  8   expensive       1453 non-null   object
#  9   healthy         1453 non-null   object
#  10  disgusting      1453 non-null   object
#  11  Like            1453 non-null   object
#  12  Age             1453 non-null   int64
#  13  VisitFrequency  1453 non-null   object
#  14  Gender          1453 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 170.4+ KB

# %%
f1 = data['Age'].values
f2 = data['VisitFrequency'].values

X = np.array(list(zip(f1,f2)))
plt.scatter(f1,f2 ,c='black',s=7)

# %%
sns.catplot(x="Like", y="Age", hue="VisitFrequency", kind="swarm", data=data)

# %%
sns.catplot(x="Like", y="Age", hue="yummy", kind="point", data=data)

# %%
sns.catplot(x="Like", y="Age", hue="disgusting", kind="point", data=data)

# %%
labels = ['Male','Female']
sizes = [data.query('Gender == "Male"').Gender.count(),data.query('Gender == "Female"').Gender.count()]
#colors
colors = ['#ffdaB9','#66b3ff']
#explsion
explode = (0.05,0.05)
plt.figure(figsize=(8,8)) 
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85,explode=explode)
p=plt.gcf()
plt.axis('equal')
p.gca().add_artist(my_circle)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot(data.Age)
plt.xlabel("Age")
plt.ylabel("Person Count")
plt.show()

# %%
plt.figure(figsize=(20,7))
gender = ['Male', 'Female']
for i in gender:
    plt.scatter(x='Age',y='Like', data=data[data['Gender']==i],s = 200 , alpha = 0.5 , label = i)
plt.legend()
plt.xlabel("Age")
plt.ylabel("Like")
plt.title("Liking according to Age")
plt.show()

# %%
merg = linkage(data,method="ward")
plt.figure(figsize=(25,10))
dendrogram(merg,leaf_rotation = 90)
plt.xlabel("data points")
plt.ylabel("euclidean distance")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29316/1770712000.py in <module>
# ----> 1 merg = linkage(data,method="ward")
#       2 plt.figure(figsize=(25,10))
#       3 dendrogram(merg,leaf_rotation = 90)
#       4 plt.xlabel("data points")
#       5 plt.ylabel("euclidean distance")
#
# ~\anaconda3\lib\site-packages\scipy\cluster\hierarchy.py in linkage(y, method, metric, optimal_ordering)
#    1044         raise ValueError("Invalid method: {0}".format(method))
#    1045
# -> 1046     y = _convert_to_double(np.asarray(y, order='c'))
#    1047
#    1048     if y.ndim == 1:
#
# ~\anaconda3\lib\site-packages\scipy\cluster\hierarchy.py in _convert_to_double(X)
#    1570 def _convert_to_double(X):
#    1571     if X.dtype != np.double:
# -> 1572         X = X.astype(np.double)
#    1573     if not X.flags.contiguous:
#    1574         X = X.copy()
# ...

# %%
data['Age'] = data['Age'].astype(str)

# %%
data.dtypes
# Out:
# yummy             object
# convenient        object
# spicy             object
# fattening         object
# greasy            object
# fast              object
# cheap             object
# tasty             object
# expensive         object
# healthy           object
# disgusting        object
# Like              object
# Age               object
# VisitFrequency    object
# Gender            object
# dtype: object

# %%
cost = []
K = range(1,5)
for num_clusters in list(K):
    kmode = KModes(n_clusters=num_clusters, init = "random", n_init = 5, verbose=1)
    kmode.fit_predict(data)
    cost.append(kmode.cost_)
    
plt.plot(K, cost, 'bx-')
plt.xlabel('No. of clusters')
plt.ylabel('Cost')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 8511.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 8511.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 8511.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 8511.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 8511.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 150, cost: 6987.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 326, cost: 7017.0
# ...

# %%
# Building the model with 3 clusters
kmode = KModes(n_clusters=3, init = "random", n_init = 5, verbose=1)
clusters = kmode.fit_predict(data)
clusters
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 331, cost: 6850.0
# Run 1, iteration: 2/100, moves: 12, cost: 6850.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 212, cost: 6772.0
# Run 2, iteration: 2/100, moves: 5, cost: 6772.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 61, cost: 7092.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 258, cost: 6635.0
# Run 4, iteration: 2/100, moves: 127, cost: 6624.0
# Run 4, iteration: 3/100, moves: 6, cost: 6624.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 431, cost: 6680.0
# Run 5, iteration: 2/100, moves: 98, cost: 6680.0
# Best run was number 4
# ...

# %%
data.insert(0, "Cluster", clusters, True)
data
# Out:
#       Cluster yummy convenient spicy fattening greasy fast cheap tasty  \
# 0           2    No        Yes    No       Yes     No  Yes   Yes    No
# 1           2   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes
# 2           0    No        Yes   Yes       Yes    Yes  Yes    No   Yes
# 3           2   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes
# 4           1    No        Yes    No       Yes    Yes  Yes   Yes    No
# ...       ...   ...        ...   ...       ...    ...  ...   ...   ...
# 1448        0    No        Yes    No       Yes    Yes   No    No    No
# 1449        2   Yes        Yes    No       Yes     No   No   Yes   Yes
# 1450        1   Yes        Yes    No       Yes     No  Yes    No   Yes
# 1451        1   Yes        Yes    No        No     No  Yes   Yes   Yes
# 1452        0    No        Yes    No       Yes    Yes   No    No    No
#
#      expensive healthy disgusting          Like Age      VisitFrequency  \
# ...
